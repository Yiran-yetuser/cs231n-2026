# %%
# from google.colab import drive

# drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs231n/assignments/assignment3/'
# FOLDERNAME = None

# assert FOLDERNAME is not None, "[!] Enter the foldername."

# ============ 本地环境配置（替代上面的 Colab 模板）============
import os, sys

# 确保工作目录是 assignment3，保证能 import 本地 cs231n 包
ASSIGNMENT_DIR = '/Users/yyz/Documents/my_code/cs231n/assignments/assignment3'
os.chdir(ASSIGNMENT_DIR)
if ASSIGNMENT_DIR not in sys.path:
    sys.path.insert(0, ASSIGNMENT_DIR)

# 标准库与第三方库
import random
import numpy as np
import matplotlib.pyplot as plt
import torch  # a3 基于 PyTorch

# matplotlib 图像内嵌显示（Jupyter magic）
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# 自动重载改动过的 cs231n 模块（Jupyter magic）
# %load_ext autoreload
# %autoreload 2

# 数据说明：
# - CIFAR-10 / imagenet_val_25.npz 已通过软链共享就位，无需下载；
# - COCO caption（coco_captioning）未下载：Self_Supervised_Learning、
#   Transformer_Captioning 需要，请用 Colab 当下载器或 curl 拉取后放到
#   assignment3/cs231n/datasets/coco_captioning/；
# - DDPM 需要 Emoji 数据集，同样需自行下载到 datasets/；
# - CLIP/ViT 等预训练权重通常由 torch hub / transformers 在运行时自动下载（需联网）。

# %% [markdown]
# # Collect Submission - Zip + Generate PDF
#
# <font color="red">**Note:** Remember to execute ALL notebooks' cells before this step. We won't be regrading missing cell outputs.</font>
#
# Run this notebook once you have completed all the other notebooks.
#
# It will:
#
# * Generate a zip file of your code (`.py` and `.ipynb`) called `a3_code_submission.zip`.
# * Convert all notebooks into a single PDF file called `a3_inline_submission.pdf`.
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit a3_code_submission.zip and a3_inline_submission.pdf to Gradescope. ###`
#
# Make sure to download the zip and pdf file locally to your computer, then submit to Gradescope. Congrats on successfully completing the assignment!

# %%
# %cd /content/drive/My\ Drive/$FOLDERNAME
# !sudo apt-get update
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2
# !bash collectSubmission.sh
