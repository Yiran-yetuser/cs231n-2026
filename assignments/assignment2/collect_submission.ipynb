# %%
# from google.colab import drive

# drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs231n/assignments/assignment1/'
# FOLDERNAME = 'cs231n/assignments/assignment2/'

# assert FOLDERNAME is not None, "[!] Enter the foldername."

# import sys
# sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# ============ 本地环境配置（替代上面的 Colab 模板）============
import os, sys

# 确保工作目录是 assignment2，保证能 import 本地 cs231n 包
ASSIGNMENT_DIR = '/Users/yyz/Documents/my_code/cs231n/assignments/assignment2'
os.chdir(ASSIGNMENT_DIR)
if ASSIGNMENT_DIR not in sys.path:
    sys.path.insert(0, ASSIGNMENT_DIR)

# 标准库与第三方库
import random
import numpy as np
import matplotlib.pyplot as plt
import torch  # a2 基于 PyTorch

# matplotlib 图像内嵌显示（Jupyter magic）
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# 自动重载改动过的 cs231n 模块（Jupyter magic）
# %load_ext autoreload
# %autoreload 2

# 数据说明：
# - CIFAR-10 / imagenet_val_25.npz 已通过软链共享就位，无需下载；
# - ConvolutionalNetworks 需要的 im2col_cython.so 已在 a2/cs231n 编译好；
# - RNN 作业还需 COCO caption 数据集（coco_caption），若缺失需另行下载
#   （toronto 源较慢，建议用 Colab 当下载器搬回本地）。

# %% [markdown]
# # Collect Submission - Zip + Generate PDF
#
# Run this notebook once you have completed all the other notebooks: `BatchNormalization.ipynb`, `Dropout.ipynb`, `ConvolutionalNetworks.ipynb` and `PyTorch.ipynb`, `RNN_Captioning_pytorch.ipynb`.
#
# It will:
#
# * Generate a zip file of your code (`.py` and `.ipynb`) called `a2.zip`.
# * Convert all notebooks into a single PDF file called `assignment.pdf`.
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit a2.zip and the pdfs to Gradescope. ###`
#
# Make sure to download the zip and pdf file locally to your computer, then submit to Gradescope. Congrats on succesfully completing the assignment!

# %%
# %cd /content/drive/My\ Drive/$FOLDERNAME
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2
# !bash collectSubmission.sh
